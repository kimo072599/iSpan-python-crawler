# %%
import requests
from bs4 import BeautifulSoup as bs

url = "https://www.ptt.cc/bbs/Gossiping/index.html"
cookies = {
    "over18" : "1"
}
r = requests.get(url, cookies = cookies)
soup = bs(r.text, "lxml")

print(soup)
# 到這邊是確定有爬到網頁 html，接下來觀察 html 還是要去網頁看比較好看
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# <script>
# (() => {
#     if (document.cookie.indexOf('over18=1') === -1) {
# 	location = 'https://www.ptt.cc/ask/over18?from=' + encodeURIComponent(location.pathname);
#     }
# })();
# </script>
# </head>
# ...

# %%
containers = soup.select(".r-ent")
# print(containers)
# print(containers[0])
containers = soup.select(".r-ent .title")
# print(containers)
# print(containers[0])
title_elements = soup.select(".r-ent .title a")
print(title_elements)
# Out:
# [<a href="/bbs/Gossiping/M.1763305405.A.C31.html">[問卦] 你說明天 就等明天 明天似乎離我太遙遠?</a>, <a href="/bbs/Gossiping/M.1763305412.A.648.html">Re: [問卦] 明天發雞排的機率？</a>, <a href="/bbs/Gossiping/M.1763305514.A.360.html">[問卦] 轉生到古代被皇帝下令幹妃嬪怎解？</a>, <a href="/bbs/Gossiping/M.1763305649.A.EA6.html">Re: [新聞] 賴清德宣布成立「兒童及家庭署」！石崇良</a>, <a href="/bbs/Gossiping/M.1763305700.A.AD6.html">[問卦] 到底何時才能執行周休三日?</a>, <a href="/bbs/Gossiping/M.1763305778.A.ADC.html">Re: [問卦] 館又贏？</a>, <a href="/bbs/Gossiping/M.1763305790.A.E7F.html">Re: [問卦] 大師兄：你搞清楚 是沒我們就沒有館長</a>, <a href="/bbs/Gossiping/M.1763305826.A.4AE.html">Re: [問卦] 脆：楓康比全聯好，力挺楓康</a>, <a href="/bbs/Gossiping/M.1737398137.A.644.html">[公告] 八卦板板規(2025.01.21)</a>, <a href="/bbs/Gossiping/M.1759065775.A.9B4.html">Re: [問卦] 請勿前往光復區，鏟子超人任務艱鉅，病例增。</a>, <a href="/bbs/Gossiping/M.1761980569.A.84C.html">[公告] 【八卦美學獎】梗圖吐槽，共鳴豹紋笑翻！</a>, <a href="/bbs/Gossiping/M.1763261445.A.26D.html">[公告] 11/15 八卦踢報十大頭條 11月協尋 置底閒聊</a>, <a href="/bbs/Gossiping/M.1763261838.A.61D.html">[公告] 11/16
# ...

# %%
# 因為 href 裡沒有給完整網址，所以要自己給前贅
prefix = "https://www.ptt.cc"

for ele in title_elements:
    print(f"標題：{ele.get_text()} 網址：{prefix + ele["href"]}")
# Out:
# 標題：[問卦] 你說明天 就等明天 明天似乎離我太遙遠? 網址：https://www.ptt.cc/bbs/Gossiping/M.1763305405.A.C31.html
# 標題：Re: [問卦] 明天發雞排的機率？ 網址：https://www.ptt.cc/bbs/Gossiping/M.1763305412.A.648.html
# 標題：[問卦] 轉生到古代被皇帝下令幹妃嬪怎解？ 網址：https://www.ptt.cc/bbs/Gossiping/M.1763305514.A.360.html
# 標題：Re: [新聞] 賴清德宣布成立「兒童及家庭署」！石崇良 網址：https://www.ptt.cc/bbs/Gossiping/M.1763305649.A.EA6.html
# 標題：[問卦] 到底何時才能執行周休三日? 網址：https://www.ptt.cc/bbs/Gossiping/M.1763305700.A.AD6.html
# 標題：Re: [問卦] 館又贏？ 網址：https://www.ptt.cc/bbs/Gossiping/M.1763305778.A.ADC.html
# 標題：Re: [問卦] 大師兄：你搞清楚 是沒我們就沒有館長 網址：https://www.ptt.cc/bbs/Gossiping/M.1763305790.A.E7F.html
# 標題：Re: [問卦] 脆：楓康比全聯好，力挺楓康 網址：https://www.ptt.cc/bbs/Gossiping/M.1763305826.A.4AE.html
# 標題：[公告] 八卦板板規(2025.01.21) 網址：https://www.ptt.cc/bbs/Gossiping/M.1737398137.A.644.html
# 標題：Re: [問卦] 請勿前往光復區，鏟子超人任務艱鉅，病例增。 網址：https://www.ptt.cc/bbs/Gossiping/M.1759065775.A.9B4.html
# 標題：[公告] 【八卦美學獎】梗圖吐槽，共鳴豹紋笑翻！ 網址：https://www.ptt.cc/bbs/Gossiping/M.1761980569.A.84C.html
# ...

# %%
for ele in title_elements:
    ppt_response = requests.get(prefix + ele["href"])
    print(ppt_response.text)
    break
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>[問卦] 你說明天 就等明天 明天似乎離我太遙遠? - 看板 Gossiping - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="大家安安
# 今天看到雞排文的新聞
# 平時對祭品文是習以為常懶得理會的 但竟不照規矩放鴿子
# 反而激起本宅的勝負欲 非要吃到不可
# 但時間變成星期一 就不可能惹 更不用說還要登記學生證 變成台大自產自銷
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="[問卦] 你說明天 就等明天 明天似乎離我太遙遠?">
# <meta property="og:description" content="大家安安
# 今天看到雞排文的新聞
# 平時對祭品文是習以為常懶得理會的 但竟不照規矩放鴿子
# 反而激起本宅的勝負欲 非要吃到不可
# 但時間變成星期一 就不可能惹 更不用說還要登記學生證 變成台大自產自銷
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Gossiping/M.1763305405.A.C31.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# ...
