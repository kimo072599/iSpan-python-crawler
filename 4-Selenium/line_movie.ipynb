# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
'''
Service 現在可以不用給了，所以這幾句都可以省略
# from selenium.webdriver.chrome.service import Service
# 建立 Service 物件，指定 chromedriver.exe 的路徑
# service = Service('chromedriver/chromedriver-win64/chromedriver.exe')
'''

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

# %%
movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
print(len(movie_list))

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
import time
time.sleep(2)
movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
print(f"目前數量:{len(movie_list)}")
# Out:
# 目前顯示數量:80

# %%
last_movie = movie_list[-1]
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
    if last_movie == movie_list[-1]:
        break
    last_movie = movie_list[-1]
    print(f"目前數量:{len(movie_list)}")

# %%
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".detailListItem-title").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".detailListItem-engTitle").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".iconInfo-text").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href"))
# Out:
# 闇黑電話2
# Black Phone 2
# 8.6
# • 1小時54分 • 2025年10月17日上映
# https://today.line.me/tw/v3/movie/KwMWjOo/1

# %%
all_movie_info = []
for movie in movie_list:
    movie_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-title").text
    movie_en_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-engTitle").text
    movie_score = movie.find_element(By.CSS_SELECTOR, ".iconInfo-text").text
    movie_time = movie.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name" : movie_name,
        "English name" : movie_en_name,
        "Score" : movie_score,
        "Time" : movie_time,
        "Link" : movie_link
    })
print(all_movie_info)
# Out:
# [{'name': '終極戰士：殺戮星球', 'English name': 'Predator: Badlands', 'Score': '9.1', 'Time': '• 1小時47分 • 2025年11月06日上映', 'Link': 'https://today.line.me/tw/v3/movie/5y7K1gV/1'}, {'name': '劇場版『鏈鋸人 蕾潔篇』', 'English name': 'Chainsaw Man – The Movie: Reze Arc', 'Score': '9.1', 'Time': '• 1小時40分 • 2025年09月24日上映', 'Link': 'https://today.line.me/tw/v3/movie/qo9a3zy/1'}, {'name': '泥娃娃', 'English name': 'Mudborn', 'Score': '8.6', 'Time': '• 1小時51分 • 2025年10月09日上映', 'Link': 'https://today.line.me/tw/v3/movie/OpgpXxj/1'}, {'name': '自殺通告', 'English name': 'Deadline', 'Score': '7.6', 'Time': '• 1小時57分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/YavOK1M/1'}, {'name': '國寶', 'English name': 'KOKUHO', 'Score': '9.3', 'Time': '• 2小時55分 • 2025年10月23日上映', 'Link': 'https://today.line.me/tw/v3/movie/60n71q6/1'}, {'name': '96分鐘', 'English name': '96 Minutes', 'Score': '8.7', 'Time': '• 1小時58分 • 2025年09月05日上映', 'Link': 'https://today.line.me/tw/v3/movie/rmwLQJY/1'}, {'name': '暴蜂尼亞', 'English name': 'Bugonia', 'Score': '10', 'Time': '• 1小時58分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/XYwJD89/1'}, {'name': '劇場版「鬼滅之刃」無限城篇 第一章 猗窩座再襲', 'English name': 'Demon Slayer: Kimetsu no Yaiba Infinity Castle', 'Score': '9.5', 'Time': '• 2小時35分 • 2025年08月08日上映', 'Link': 'https://today.line.me/tw/v3/movie/8nz7EpZ/1'}, {'name': '去死吧，親愛的', 'English name': 'Die My Love', 'Score': '8.9', 'Time': '• 1小時58分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/7Nz3Qyk/1'}, {'name': '女孩', 'English name': 'Girl', 'Score': '8.5', 'Time': '• 2小時04分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/PGNny9o/1'}, {'name': '左撇子女孩', 'English name': 'Left-Handed Girl', 'Score': '7.4', 'Time': '• 1小時48分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/vXV0ZM0/1'}, {'name': '鬼聲泣3', 'English name': 'Tee Yod 3', 'Score': '8.2', 'Time': '• 1小時44分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/eLOOzwK/1'}, {'name': 'G-DRAGON IN CINEMA [Übermensch]', 'English name': 'G-DRAGON IN CINEMA [Übermensch]', 'Score': '9.6', 'Time': '• 1小時46分 • 2025年10月29日上映', 'Link': 'https://today.line.me/tw/v3/movie/JPO827q/1'}, {'name': '機動戰士鋼彈 鐵血孤兒 追尋兀爾德 -小小挑戰者的軌跡-', 'English name': "Special Edition: Mobile Suit Gundam Iron-Blooded Orphans Urdr-Hunt ''-Path of the Little Challenger- ''", 'Score': '0.0', 'Time': '• 1小時18分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/Ya56JeN/1'}, {'name': '鬼童伴', 'English name': 'Muslihat', 'Score': '9.5', 'Time': '• 1小時30分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/YavJlD8/1'}, {'name': '愉快動物餅 大電影', 'English name': 'Dream Animals THE MOVIE', 'Score': '0.0', 'Time': '• 1小時30分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/kENqY1w/1'}, {'name': '只為你遺憾', 'English name': 'Regretting You', 'Score': '7.5', 'Time': '• 1小時56分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/Yav60jP/1'}, {'name': 'F1電影', 'English name': 'F1 The Movie', 'Score': '9.6', 'Time': '• 2小時35分 • 2025年06月25日上映', 'Link': 'https://today.line.me/tw/v3/movie/8nzgj1q/1'}, {'name': '一百公尺。', 'English name': '100 Meters', 'Score': '9.8', 'Time': '• 1小時46分 • 2025年10月03日上映', 'Link': 'https://today.line.me/tw/v3/movie/2DjEeej/1'}, {'name': 'ONE IN A MILL10N', 'English name': 'ONE IN A MILL10N', 'Score': '9.5', 'Time': '• 2小時01分 • 2025年10月20日上映', 'Link': 'https://today.line.me/tw/v3/movie/5yNnB2M/1'}, {'name': '鋼琴家們的秘密煉金術', 'English name': 'The Alchemy of The Piano', 'Score': '0.0', 'Time': '• 1小時30分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/gzrm31N/1'}, {'name': '蟲', 'English name': 'Locust', 'Score': '8.0', 'Time': '• 2小時15分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/BE35DZz/1'}, {'name': '電影版吸吸吸吸吸血鬼', 'English name': 'Babanba Banban Vampire', 'Score': '10', 'Time': '• 1小時45分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/60napRa/1'}, {'name': '碰碰狐和貝貝彬歡唱電影：奇幻世界大冒險', 'English name': 'Bebefinn Sing-Along Movie: Into the Pinkfong World', 'Score': ' ...

# %%
from pprint import pprint
pprint(all_movie_info[0])
# Out:
# {'English name': 'Predator: Badlands',
#  'Link': 'https://today.line.me/tw/v3/movie/5y7K1gV/1',
#  'Score': '9.1',
#  'Time': '• 1小時47分 • 2025年11月06日上映',
#  'name': '終極戰士：殺戮星球'}
