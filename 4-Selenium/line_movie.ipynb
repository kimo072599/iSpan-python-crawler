# %% [markdown]
# ## 主程式打包在這

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
'''
Service 現在可以不用給了，所以這幾句都可以省略
# from selenium.webdriver.chrome.service import Service
# 建立 Service 物件，指定 chromedriver.exe 的路徑
# service = Service('chromedriver/chromedriver-win64/chromedriver.exe')
'''

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
    if last_movie == movie_list[-1]:
        break
    last_movie = movie_list[-1]

all_movie_info = []
for movie in movie_list:
    movie_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-title").text
    movie_en_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-engTitle").text
    movie_score = movie.find_element(By.CSS_SELECTOR, ".iconInfo-text").text
    movie_time = movie.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name" : movie_name,
        "English name" : movie_en_name,
        "Score" : movie_score,
        "Time" : movie_time,
        "Link" : movie_link
    })

def get_comment(url):
    driver.get(url)
    driver.find_element(By.CSS_SELECTOR, "ul.tabs-list.movie li:nth-child(3)").click()
    time.sleep(1)
    comment_cards = driver.find_elements(By.CSS_SELECTOR, ".css-hnvcda")

    comment_info = []
    for comment_card in comment_cards:
        user = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser").text
        
        comment_date = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser-createdTime").text
        
        star_map = {
        "M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z":2,
        "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z":1,
        "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z":0
        }
        ratingStars = comment_card.find_elements(By.CSS_SELECTOR,".ratingStar path")
        grade = 0
        for star in ratingStars:
            path_d = star.get_attribute("d")
            grade += star_map[path_d]

        comment = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemContent").text
        
        comment_info.append({
            "comment_user": user,
            "grade": grade,
            "comment_date": comment_date,
            "comment": comment
        })
        
    return comment_info
get_comment(all_movie_info[0]["Link"])
# Out:
# [{'comment_user': '菲力',
#   'grade': 5,
#   'comment_date': '11月14日22:45',
#   'comment': '不能說不好看，只是略感失望，舊騎士在整場戲有點多餘，幾乎沒給他們發揮的空間，讓人懷疑導演跟編劇刻意在賣情懷，殘酷一點的說，感覺像是新騎士踩著舊騎士的肩膀上位@@'},
#  {'comment_user': 'Syuan🐟',
#   'grade': 9,
#   'comment_date': '11月15日11:04',
#   'comment': '有種要新舊交替的感覺，但...我還是喜歡原本的五騎士\n9分給我喜歡的五騎士'},
#  {'comment_user': 'kkkww Liu',
#   'grade': 6,
#   'comment_date': '11月15日18:04',
#   'comment': '要推新人來讓ip走遠不反對，可是跟前二集比劇情松散魔術情結都輸前二集太多，真有第四集不會再進電影院觀看了'},
#  {'comment_user': '凱鑫企業/玉龍跆拳道 葉佳欣(John)',
#   'grade': 5,
#   'comment_date': '1天前',
#   'comment': '普普 小失望'},
#  {'comment_user': 'WU',
#   'grade': 8,
#   'comment_date': '2天前',
#   'comment': '好看 邏輯交代滿清楚的 劇情新穎'},
#  {'comment_user': 'Wayne',
#   'grade': 7,
#   'comment_date': '2天前',
#   'comment': '還可以，劇情算是交代的滿清楚的\n帶出新成員'},
#  {'comment_user': '昱凱',
#   'grade': 4,
#   'comment_date': '2天前',
#   'comment': '真的是很難看的續集\n我也是很欣賞原先的5人組合\n但這些知名的5人只在頭尾組合\n中間讓這些新人擔任主角\n我一度在電影院內睡著\n真的不知道編劇為何要做這樣的安排\n很無言💤'},
#  {'comment_user': '雯 ꗯ̤̮ ꗯ꙼̈',
#   'grade': 5,
#   'comment_date': '11月15日01:46',
#   'comment': '略失望'},
#  {'comment_user': '沛公',
#   'grade': 7,
#   'comment_date': '1天前',
#   'comment': '為續作鋪陳，尚可。'},
#  {'comment_user': '🐶葶🐈\u200d⬛',
#   'grade': 5,
#   'comment_date': '2天前',
#   'comment': '嗯⋯真的覺得還好，蠻失望的⋯沒有前兩部精彩'},
#  {'comment_user': '快乐天堂🇦🇷',
#   'grade': 8,
#   'comment_date': '6小時前',
#   'comment': '長江後浪推前浪'},
#  {'comment_user': 'James',
#   'grade': 3,
#   'comment_date': '13小時前',
#   'comment': '第一集 滿新鮮感 不錯看⋯第二⋯覺得普普⋯⋯第三就不會想去看⋯⋯ㄞ'},
#  {'comment_user': '陶知☃️',
#   'grade': 3,
#   'comment_date': '20小時前',
#   'comment': '很失望的續集，幾乎舊騎士只是配角的感覺\n出事都是他們扛⋯新騎士內容佔據了大半\n唉再有續集也不會進電影看了'},
#  {'comment_user': '❤︎獅獅☻',
#   'grade': 7,
#   'comment_date': '1天前',
#   'comment': '劇情普普 有點老梗 但整體來說還是可以。'},
#  {'comment_user': 'David Chen',
#   'grade': 7,
#   'comment_date': '2天前',
#   'comment': '雖說舊班底有點老化，但還是比新人有魅力'},
#  {'comment_user': '賴彥廷',
#   'grade': 10,
#   'comment_date': '11月14日15:50',
#   'comment': '好看，有點像是老騎士帶新騎士的感覺'}]

# %% [markdown]
# ## 測試用的 cell

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
'''
Service 現在可以不用給了，所以這幾句都可以省略
# from selenium.webdriver.chrome.service import Service
# 建立 Service 物件，指定 chromedriver.exe 的路徑
# service = Service('chromedriver/chromedriver-win64/chromedriver.exe')
'''

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

# %%
movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
print(len(movie_list))
# Out:
# 20

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
import time
time.sleep(2)
movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
print(f"目前數量:{len(movie_list)}")
# Out:
# 目前數量:30

# %%
last_movie = movie_list[-1]
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
    if last_movie == movie_list[-1]:
        break
    last_movie = movie_list[-1]
    print(f"目前數量:{len(movie_list)}")
# Out:
# 目前數量:40
# 目前數量:50
# 目前數量:60
# 目前數量:70
# 目前數量:80
# 目前數量:90

# %%
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".detailListItem-title").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".detailListItem-engTitle").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".iconInfo-text").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href"))
# Out:
# 珠寶師遺落在時光裡的愛
# The Goldsmith's Secret
# 10
# • 1小時39分 • 2025年10月31日上映
# https://today.line.me/tw/v3/movie/9m7WJzq/1

# %%
all_movie_info = []
for movie in movie_list:
    movie_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-title").text
    movie_en_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-engTitle").text
    movie_score = movie.find_element(By.CSS_SELECTOR, ".iconInfo-text").text
    movie_time = movie.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name" : movie_name,
        "English name" : movie_en_name,
        "Score" : movie_score,
        "Time" : movie_time,
        "Link" : movie_link
    })
print(all_movie_info)
# Out:
# [{'name': '出神入化3', 'English name': 'Now You See Me：Now You Don’t', 'Score': '6.2', 'Time': '• 1小時53分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/JPMx3ox/1'}, {'name': '逃亡遊戲', 'English name': 'The Running Man', 'Score': '7.5', 'Time': '• 2小時13分 • 2025年11月12日上映', 'Link': 'https://today.line.me/tw/v3/movie/9mllw13/1'}, {'name': '終極戰士：殺戮星球', 'English name': 'Predator: Badlands', 'Score': '9.0', 'Time': '• 1小時47分 • 2025年11月06日上映', 'Link': 'https://today.line.me/tw/v3/movie/5y7K1gV/1'}, {'name': '劇場版 咒術迴戰 澀谷事變 x 死滅迴游 先行上映', 'English name': 'JUJUTSU KAISEN: Execution -Shibuya Incident×The Culling Game Begins-', 'Score': '10', 'Time': '• 1小時28分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/zNk3rOK/1'}, {'name': '劇場版『鏈鋸人 蕾潔篇』', 'English name': 'Chainsaw Man – The Movie: Reze Arc', 'Score': '9.1', 'Time': '• 1小時40分 • 2025年09月24日上映', 'Link': 'https://today.line.me/tw/v3/movie/qo9a3zy/1'}, {'name': '嚇午4點', 'English name': '4PM', 'Score': '9.5', 'Time': '• 1小時51分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/WBzPm7a/1'}, {'name': '泥娃娃', 'English name': 'Mudborn', 'Score': '8.6', 'Time': '• 1小時51分 • 2025年10月09日上映', 'Link': 'https://today.line.me/tw/v3/movie/OpgpXxj/1'}, {'name': '放飛旅行團', 'English name': 'The First Ride', 'Score': '7.3', 'Time': '• 1小時56分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/3Nw0lXr/1'}, {'name': '國寶', 'English name': 'KOKUHO', 'Score': '9.2', 'Time': '• 2小時55分 • 2025年10月23日上映', 'Link': 'https://today.line.me/tw/v3/movie/60n71q6/1'}, {'name': '自殺通告', 'English name': 'Deadline', 'Score': '7.7', 'Time': '• 1小時57分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/YavOK1M/1'}, {'name': '南方時光', 'English name': 'Before the Bright Day', 'Score': '0.0', 'Time': '• 1小時53分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/NvwVzRk/1'}, {'name': 'BLUE GIANT 藍色巨星', 'English name': 'BLUE GIANT', 'Score': '10', 'Time': '• 1小時59分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/kENwrK1/1'}, {'name': '劇場版「鬼滅之刃」無限城篇 第一章 猗窩座再襲', 'English name': 'Demon Slayer: Kimetsu no Yaiba Infinity Castle', 'Score': '9.5', 'Time': '• 2小時35分 • 2025年08月08日上映', 'Link': 'https://today.line.me/tw/v3/movie/8nz7EpZ/1'}, {'name': '96分鐘', 'English name': '96 Minutes', 'Score': '8.7', 'Time': '• 1小時58分 • 2025年09月05日上映', 'Link': 'https://today.line.me/tw/v3/movie/rmwLQJY/1'}, {'name': '暴蜂尼亞', 'English name': 'Bugonia', 'Score': '10', 'Time': '• 1小時58分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/XYwJD89/1'}, {'name': '去死吧，親愛的', 'English name': 'Die My Love', 'Score': '8.6', 'Time': '• 1小時58分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/7Nz3Qyk/1'}, {'name': '左撇子女孩', 'English name': 'Left-Handed Girl', 'Score': '7.4', 'Time': '• 1小時48分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/vXV0ZM0/1'}, {'name': '女孩', 'English name': 'Girl', 'Score': '8.5', 'Time': '• 2小時04分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/PGNny9o/1'}, {'name': '鬼聲泣3', 'English name': 'Tee Yod 3', 'Score': '8.3', 'Time': '• 1小時44分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/eLOOzwK/1'}, {'name': 'G-DRAGON IN CINEMA [Übermensch]', 'English name': 'G-DRAGON IN CINEMA [Übermensch]', 'Score': '9.6', 'Time': '• 1小時46分 • 2025年10月29日上映', 'Link': 'https://today.line.me/tw/v3/movie/JPO827q/1'}, {'name': '機動戰士鋼彈 鐵血孤兒 追尋兀爾德 -小小挑戰者的軌跡-', 'English name': "Special Edition: Mobile Suit Gundam Iron-Blooded Orphans Urdr-Hunt ''-Path of the Little Challenger- ''", 'Score': '0.0', 'Time': '• 1小時18分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/Ya56JeN/1'}, {'name': '天才琴手', 'English name': 'Prodigieuses', 'Score': '9.0', 'Time': '• 1小時49分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/l2ngP6g/1'}, {'name': '愉快動物餅 大電影', 'English name': 'Dream Animals THE MOVIE', 'Score': '0.0', 'Time': '• 1小時30分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/kENqY1w/1'}, {'name': '三分之愛', 'English name': 'Yasuko,  ...

# %%
from pprint import pprint
pprint(all_movie_info[0])
# Out:
# {'English name': 'Now You See Me：Now You Don’t',
#  'Link': 'https://today.line.me/tw/v3/movie/JPMx3ox/1',
#  'Score': '6.2',
#  'Time': '• 1小時53分 • 2025年11月14日上映',
#  'name': '出神入化3'}

# %%
driver.get(all_movie_info[0]["Link"])
time.sleep(2)
driver.find_element(By.CSS_SELECTOR, "ul.tabs-list.movie li:nth-child(3)").click()

# %%
star_map = {
    "M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z":2,
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z":1,
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z":0
}
comment_cards = driver.find_elements(By.CSS_SELECTOR, ".css-hnvcda")
user = comment_cards[0].find_element(By.CSS_SELECTOR, ".ratingCommentItemUser").text
print(user)
ratingStars = comment_cards[0].find_elements(By.CSS_SELECTOR,".ratingStar path")
print(len(ratingStars))
first_ratingStar = ratingStars[0].get_attribute("d")
print(first_ratingStar)
comment_date = comment_cards[0].find_element(By.CSS_SELECTOR, ".ratingCommentItemUser-createdTime").text
print(comment_date)
comment = comment_cards[0].find_element(By.CSS_SELECTOR, ".ratingCommentItemContent").text
print(comment)
# Out:
# 菲力
# 5
# M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z
# 11月14日22:45
# 不能說不好看，只是略感失望，舊騎士在整場戲有點多餘，幾乎沒給他們發揮的空間，讓人懷疑導演跟編劇刻意在賣情懷，殘酷一點的說，感覺像是新騎士踩著舊騎士的肩膀上位@@

# %%
grade = 0
for star in ratingStars:
    path_d = star.get_attribute("d")
    grade += star_map[path_d]
print(grade)
# Out:
# 5

# %%
def get_comment(url):
    driver.get(url)
    driver.find_element(By.CSS_SELECTOR, "ul.tabs-list.movie li:nth-child(3)").click()
    time.sleep(1)
    comment_cards = driver.find_elements(By.CSS_SELECTOR, ".css-hnvcda")

    comment_info = []
    for comment_card in comment_cards:
        user = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser").text
        
        comment_date = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser-createdTime").text
        
        star_map = {
        "M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z":2,
        "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z":1,
        "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z":0
        }
        ratingStars = comment_card.find_elements(By.CSS_SELECTOR,".ratingStar path")
        grade = 0
        for star in ratingStars:
            path_d = star.get_attribute("d")
            grade += star_map[path_d]

        comment = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemContent").text
        
        comment_info.append({
            "comment_user": user,
            "grade": grade,
            "comment_date": comment_date,
            "comment": comment
        })
        
    return comment_info

# %%
get_comment(all_movie_info[0]["Link"])
# Out:
# [{'comment_user': '菲力',
#   'grade': 5,
#   'comment_date': '11月14日22:45',
#   'comment': '不能說不好看，只是略感失望，舊騎士在整場戲有點多餘，幾乎沒給他們發揮的空間，讓人懷疑導演跟編劇刻意在賣情懷，殘酷一點的說，感覺像是新騎士踩著舊騎士的肩膀上位@@'},
#  {'comment_user': 'Syuan🐟',
#   'grade': 9,
#   'comment_date': '11月15日11:04',
#   'comment': '有種要新舊交替的感覺，但...我還是喜歡原本的五騎士\n9分給我喜歡的五騎士'},
#  {'comment_user': 'kkkww Liu',
#   'grade': 6,
#   'comment_date': '11月15日18:04',
#   'comment': '要推新人來讓ip走遠不反對，可是跟前二集比劇情松散魔術情結都輸前二集太多，真有第四集不會再進電影院觀看了'},
#  {'comment_user': '凱鑫企業/玉龍跆拳道 葉佳欣(John)',
#   'grade': 5,
#   'comment_date': '1天前',
#   'comment': '普普 小失望'},
#  {'comment_user': 'WU',
#   'grade': 8,
#   'comment_date': '2天前',
#   'comment': '好看 邏輯交代滿清楚的 劇情新穎'},
#  {'comment_user': 'Wayne',
#   'grade': 7,
#   'comment_date': '2天前',
#   'comment': '還可以，劇情算是交代的滿清楚的\n帶出新成員'},
#  {'comment_user': '昱凱',
#   'grade': 4,
#   'comment_date': '2天前',
#   'comment': '真的是很難看的續集\n我也是很欣賞原先的5人組合\n但這些知名的5人只在頭尾組合\n中間讓這些新人擔任主角\n我一度在電影院內睡著\n真的不知道編劇為何要做這樣的安排\n很無言💤'},
#  {'comment_user': '雯 ꗯ̤̮ ꗯ꙼̈',
#   'grade': 5,
#   'comment_date': '11月15日01:46',
#   'comment': '略失望'},
#  {'comment_user': '沛公',
#   'grade': 7,
#   'comment_date': '1天前',
#   'comment': '為續作鋪陳，尚可。'},
#  {'comment_user': '🐶葶🐈\u200d⬛',
#   'grade': 5,
#   'comment_date': '2天前',
#   'comment': '嗯⋯真的覺得還好，蠻失望的⋯沒有前兩部精彩'},
#  {'comment_user': '快乐天堂🇦🇷',
#   'grade': 8,
#   'comment_date': '6小時前',
#   'comment': '長江後浪推前浪'},
#  {'comment_user': 'James',
#   'grade': 3,
#   'comment_date': '13小時前',
#   'comment': '第一集 滿新鮮感 不錯看⋯第二⋯覺得普普⋯⋯第三就不會想去看⋯⋯ㄞ'},
#  {'comment_user': '陶知☃️',
#   'grade': 3,
#   'comment_date': '20小時前',
#   'comment': '很失望的續集，幾乎舊騎士只是配角的感覺\n出事都是他們扛⋯新騎士內容佔據了大半\n唉再有續集也不會進電影看了'},
#  {'comment_user': '❤︎獅獅☻',
#   'grade': 7,
#   'comment_date': '1天前',
#   'comment': '劇情普普 有點老梗 但整體來說還是可以。'},
#  {'comment_user': 'David Chen',
#   'grade': 7,
#   'comment_date': '2天前',
#   'comment': '雖說舊班底有點老化，但還是比新人有魅力'},
#  {'comment_user': '賴彥廷',
#   'grade': 10,
#   'comment_date': '11月14日15:50',
#   'comment': '好看，有點像是老騎士帶新騎士的感覺'}]
